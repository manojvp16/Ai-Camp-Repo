# %% [markdown]
# <a href="https://colab.research.google.com/github/manojvp16/Ai-Camp-Repo/blob/main/numpytutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr =np.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
a=np.array([[],[]])
a.ndim
a.shape
# Out:
# (2, 0)

# %%
arr2=np.arange(1,11,2) # start. stop, step

# %%
arr2
# Out:
# array([1, 3, 5, 7, 9])

# %%
arr=np.linspace(0,1,5)

# %%
arr
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
arr=np.logspace(1,3,3)#10^1-10^3 , 3 numbers

# %%
arr
# Out:
# array([  10.,  100., 1000.])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.zeros([2,3])
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.ones([2,3])
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
arr=np.full(10,2)#number of values and which value

# %%
arr
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
arr=np.full([2,4],7) # rows columns and default values
arr
# Out:
# array([[7, 7, 7, 7],
#        [7, 7, 7, 7]])

# %%
arr=np.empty([2,3])

# %%
arr
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
arr=np.random.rand(2,3)

# %%
arr
# Out:
# array([[0.2055766 , 0.98088699, 0.77482555],
#        [0.53303814, 0.24752054, 0.61441457]])

# %%
arr=np.random.rand(10)
arr
# Out:
# array([0.7249212 , 0.43509673, 0.71363543, 0.27028849, 0.65140353,
#        0.06604511, 0.7823307 , 0.77013444, 0.5117739 , 0.14492834])

# %%
arr=np.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr=np.array([1,2,3,4,5],dtype=np.float64)

# %%
arr
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr.dtype
# Out:
# dtype('float64')

# %%
#type casting is done uing astype() method

# %%
arr=np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
newarr=arr.astype(np.float64)
newarr
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr=np.array([[1,2,3],[4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr.ndim
# Out:
# 2

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.size
# Out:
# 6

# %%
arr.itemsize
# Out:
# 8

# %%
#reshape

# %%
arr=np.array([1,2,3,4,5,6])

# %%
reshaped = arr.reshape(3,2)
reshaped
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
reshapess=arr.reshape(2,3)
reshapess
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
oned=reshapess.ravel()

# %%
oned
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
flat = reshapess.flatten()

# %%
flat
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
reshaped
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
oned
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# Arethimatic Operation

# %%
a=np.array([1,2,3,4,5])
b=np.array([6,7,8,9,10])

# %%
print(a+b)
# Out:
# [ 7  9 11 13 15]

# %%
print(b-a)
# Out:
# [5 5 5 5 5]

# %%
print(a*b)
# Out:
# [ 6 14 24 36 50]

# %%
print(a/b) # for float
# Out:
# [0.16666667 0.28571429 0.375      0.44444444 0.5       ]

# %%
print(a//b)
# Out:
# [0 0 0 0 0]

# %%
print(b//a) # for int
# Out:
# [6 3 2 2 2]

# %%
print(a%b) # modulo
# Out:
# [1 2 3 4 5]

# %%
print(a**2) #power
# Out:
# [ 1  4  9 16 25]

# %% [markdown]
# ## **Universal Function**

# %%
arr = np.array([1,4,9,16])

# %%
print(np.sqrt(arr))
# Out:
# [1. 2. 3. 4.]

# %%
#exponential -?np.exp() ->e^x = where x is and integer

# %%
print(np.exp([1,2])) # e^1 =2.7 & e^2 =7.4
# Out:
# [2.71828183 7.3890561 ]

# %%
#sine-sine(0)

# %%
angles=np.array([0,30,45,60,90])
print(np.sin(angles))
print(np.cos(angles))
print(np.tan(angles))
# Out:
# [ 0.         -0.98803162  0.85090352 -0.30481062  0.89399666]
# [ 1.          0.15425145  0.52532199 -0.95241298 -0.44807362]
# [ 0.         -6.4053312   1.61977519  0.32004039 -1.99520041]
